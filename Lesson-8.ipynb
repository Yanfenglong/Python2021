# %%
'''
【Project 1】  Shop data loading and storage

Requirment：
1、read csv file “shop1.csv”
2、Data cleaning：
① cleaning comment and price into number style:

② commentlist can be splited into three float fields，return [flavor,environment,service]

③ Clear missing data
3、Parse data，Save as list dictionary format[{'var1':value1,'var2':value2,'var3':values,...},...,{}]
    [{'classify': 'food', 'name': 'HARSON', 'comment': 'No  comments', 'star': 'no star', 'price': 125},
    {'classify': 'food', 'name': 'BeLLE', 'comment': '74', 'star': 'four star', 'price': 48},
    {'classify': 'food', 'name': 'achette', 'comment': '265', 'star': 'four star', 'price': 21},
    ......
    ]
4、Store the new data into data.pkl file.

'''

# %%
#Step1. Open the file, and get all the columns information
f= open(r'C:\Users\everi\Desktop\shop1.csv','r',encoding='gbk')
for i in f.readlines()[:5]:
     print(i.split(',')[2]) # 5/-1 commentlist information ,star 
#     print(i.split(',')) #top 4 lines , all the data information
#cursor return to the first line
# Out:
# comment
# no
# 74                    comments
# 265                    comments
# 2748                    comments

# %%
#Step2 :cleaning comment into number style
def fcm(s):
    if 'comments' in s:
        return s.split('                    ')[0] #[400 ,comments]
    else:
        return ('ABCNo comments')
#cleaning price into number style    # [average-spend,291]
def fpr(s):
    if '￥' in s: #291
        return s.split('￥')[-1]
    else:
        return ('ABCNo  average-spend ')
#cleaning commentlist information
def fco(s):
    if len(s)==3:
#         flavor, environment,service=  s[0],s[1],s[2]
#         production = float(s[0][6:]) #flavor is not the correct, there are other types
        environment = float(s[1][11:])
        service = float(s[2][7:])
        return [environment,service]  #['flavor8.3', 'environment8.4', 'service8.5\n']
    else:
        return ('ABCNo commentlist')
f.seek(0)
for i in f.readlines()[:5]:
    cm = fcm(i.split(',')[2])
    pr = fpr(i.split(',')[4])
    co = fco(i.split(',')[-1].split('                                '))
    print(co)
# Out:
# ABCNo commentlist
# [8.4, 8.5]
# [7.6, 7.4]
# [7.2, 7.2]
# [8.5, 8.4]

# %%
#Step3 Clear missing data,Parse data，Save as list dictionary format
datalist = []
sum = 0
f.seek(0)
for i in f.readlines()[1:]:  #all the data in csv file, 1264 items
    data = i.split(',')
    classify,name,comment = data[0],data[1],fcm(data[2])
    star,price = data[3],fpr(data[4])
    commentlist = fco(i.split(',')[-1].split('                                '))
    environment = commentlist[0]
    service = commentlist[1]
    if 'ABC' not in [comment,price,commentlist]:
        sum += 1
        #write sth
        new_data = [
            ["classify",classify],
            ["name",name],
            ["comment",comment],
            ["star",star],["price",price],["environment",environment],
            ["service",service]
        ]
        datalist.append(dict(new_data))
    else:
        continue
print(datalist)
print(sum)
# Out:
# [{'classify': 'food', 'name': 'HARSON', 'comment': 'ABCNo comments', 'star': 'no star', 'price': '125', 'environment': 8.4, 'service': 8.5}, {'classify': 'food', 'name': 'BeLLE', 'comment': '74', 'star': 'four star', 'price': '48', 'environment': 7.6, 'service': 7.4}, {'classify': 'food', 'name': 'achette', 'comment': '265', 'star': 'four star', 'price': '21', 'environment': 7.2, 'service': 7.2}, {'classify': 'food', 'name': 'HONGKEE', 'comment': '2748', 'star': 'five star', 'price': '142', 'environment': 8.5, 'service': 8.4}, {'classify': 'food', 'name': 'WHAT FOR', 'comment': '5', 'star': 'four star', 'price': 'ABCNo  average-spend ', 'environment': 6.8, 'service': 7.5}, {'classify': 'food', 'name': 'Gabor', 'comment': '785', 'star': 'four star', 'price': '24', 'environment': 7.2, 'service': 7.2}, {'classify': 'food', 'name': 'Joy&Mario', 'comment': '3779', 'star': 'five star', 'price': '70', 'environment': 8.6, 'service': 8.6}, {'classify': 'food', 'name': 'Cabbeen', 'comment': '458', 'star': 'four star', 'price': '14', 'environment': 6.5, 'service': 6.5}, {'classify': 'food', 'name': 'DESICNICE', 'comment': '1280', 'star': 'beyond four star', 'price': '47', 'environment': 7.5, 'service': 7.6}, {'classify': 'food', 'name': 'VERO MODA', 'comment': '85', 'star': 'five star', 'price': '81', 'environment': 8.9, 'service': 9.0}, {'classify': 'food', 'name': 'ZARA', 'comment': '2', 'star': 'four star', 'price': 'ABCNo  average-spend ', 'environment': 7.0, 'service': 7.0}, {'classify': 'food', 'name': 'GRSAGA', 'comment': '30', 'star': 'beyond four star', 'price': '17', 'environment': 8.0, 'service': 7.7}, {'classify': 'food', 'name': 'Wetnwind', 'comment': '988', 'star': 'beyond four star', 'price': '150', 'environment': 8.4, 'service': 8.0}, {'classify': 'food', 'name': 'LALABOBO', 'comment': '152', 'star': 'four star', 'price': '16', 'environment': 7.1, 'service': 7.2}, {'classify': 'food', 'name': "D'modes", 'comment': '72', 'star': 'four star', 'price': '21', 'environment': 7.4, 'service': 7.6}, {'classify': 'food', 'name': 'le saunda', 'comment': '3627', 'star': 'beyond four star', 'price': '99', 'environment': 8.5, 'service': 8.6}, {'classify': 'food', 'name': 'ecco', 'comment': '4', 'star': 'four star', 'price': 'ABCNo  average-spend ', 'environment': 7.4, 'service': 7.4}, {'classify': 'food', 'name': 'STACCATO', 'comment': '336', 'star': 'four star', 'price': '79', 'environment': 7.6, 'service': 7.7}, {'classify': 'food', 'name': 'Bata', 'comment': '264', 'star': 'beyond four star', 'price': '48', 'environment': 7.7, 'service': 7.8}, {'classify': 'food', 'name': 'BASTO', 'comment': '4', 'star': 'three star', 'price': 'ABCNo  average-spend ', 'environment': 6.8, 'service': 6.9}, {'classify': 'food', 'name': "millie's", 'comment': '67', 'star': 'beyond four star', 'price': '26', 'environment': 8.4, 'service': 8.4}, {'classify': 'food', 'name': 'J.Benato', 'comment': '226', 'star': 'five star', 'price': '47', 'environment': 8.5, 'service': 8.2}, {'classify': 'food', 'name': 'Satchi', 'comment': '2', 'star': 'four star', 'price': 'ABCNo  average-spend ', 'environment': 7.2, 'service': 7.2}, {'classify': 'food', 'name': 'KISSCAT', 'comment': '375', 'star': 'three star', 'price': '35', 'environment': 7.2, 'service': 6.5}, {'classify': 'food', 'name': 'JOy&peace', 'comment': '830', 'star': 'beyond four star', 'price': '165', 'environment': 7.7, 'service': 7.9}, {'classify': 'food', 'name': 'D:FUSE', 'comment': '15', 'star': 'four star', 'price': '14', 'environment': 7.1, 'service': 7.1}, {'classify': 'food', 'name': 'ginajone', 'comment': '1', 'star': 'four star', 'price': 'ABCNo  average-spend ', 'environment': 7.2, 'service': 7.6}, {'classify': 'food', 'name': 'YESCOLOR', 'comment': '1113', 'star': 'beyond four star', 'price': '36', 'environment': 7.4, 'service': 7.4}, {'classify': 'food', 'name': 'YEZI', 'comment': 'ABCNo comments', 'star': 'four star', 'price': 'ABCNo  average-spend ', 'environment': 6.9, 'service': 6.9}, {' ...
# 1264

# %%
# Step4:Store the new data into data.pkl file.
import pickle
f= open(r'C:\Users\everi\Desktop\data.pkl','wb')
pickle.dump(datalist,f) #store
f.close()
f= open(r'C:\Users\everi\Desktop\data.pkl','rb') #read binary
st = pickle.load(f)
print(st)
# Out:
# [{'classify': 'food', 'name': 'HARSON', 'comment': 'ABCNo comments', 'star': 'no star', 'price': '125', 'environment': 8.4, 'service': 8.5}, {'classify': 'food', 'name': 'BeLLE', 'comment': '74', 'star': 'four star', 'price': '48', 'environment': 7.6, 'service': 7.4}, {'classify': 'food', 'name': 'achette', 'comment': '265', 'star': 'four star', 'price': '21', 'environment': 7.2, 'service': 7.2}, {'classify': 'food', 'name': 'HONGKEE', 'comment': '2748', 'star': 'five star', 'price': '142', 'environment': 8.5, 'service': 8.4}, {'classify': 'food', 'name': 'WHAT FOR', 'comment': '5', 'star': 'four star', 'price': 'ABCNo  average-spend ', 'environment': 6.8, 'service': 7.5}, {'classify': 'food', 'name': 'Gabor', 'comment': '785', 'star': 'four star', 'price': '24', 'environment': 7.2, 'service': 7.2}, {'classify': 'food', 'name': 'Joy&Mario', 'comment': '3779', 'star': 'five star', 'price': '70', 'environment': 8.6, 'service': 8.6}, {'classify': 'food', 'name': 'Cabbeen', 'comment': '458', 'star': 'four star', 'price': '14', 'environment': 6.5, 'service': 6.5}, {'classify': 'food', 'name': 'DESICNICE', 'comment': '1280', 'star': 'beyond four star', 'price': '47', 'environment': 7.5, 'service': 7.6}, {'classify': 'food', 'name': 'VERO MODA', 'comment': '85', 'star': 'five star', 'price': '81', 'environment': 8.9, 'service': 9.0}, {'classify': 'food', 'name': 'ZARA', 'comment': '2', 'star': 'four star', 'price': 'ABCNo  average-spend ', 'environment': 7.0, 'service': 7.0}, {'classify': 'food', 'name': 'GRSAGA', 'comment': '30', 'star': 'beyond four star', 'price': '17', 'environment': 8.0, 'service': 7.7}, {'classify': 'food', 'name': 'Wetnwind', 'comment': '988', 'star': 'beyond four star', 'price': '150', 'environment': 8.4, 'service': 8.0}, {'classify': 'food', 'name': 'LALABOBO', 'comment': '152', 'star': 'four star', 'price': '16', 'environment': 7.1, 'service': 7.2}, {'classify': 'food', 'name': "D'modes", 'comment': '72', 'star': 'four star', 'price': '21', 'environment': 7.4, 'service': 7.6}, {'classify': 'food', 'name': 'le saunda', 'comment': '3627', 'star': 'beyond four star', 'price': '99', 'environment': 8.5, 'service': 8.6}, {'classify': 'food', 'name': 'ecco', 'comment': '4', 'star': 'four star', 'price': 'ABCNo  average-spend ', 'environment': 7.4, 'service': 7.4}, {'classify': 'food', 'name': 'STACCATO', 'comment': '336', 'star': 'four star', 'price': '79', 'environment': 7.6, 'service': 7.7}, {'classify': 'food', 'name': 'Bata', 'comment': '264', 'star': 'beyond four star', 'price': '48', 'environment': 7.7, 'service': 7.8}, {'classify': 'food', 'name': 'BASTO', 'comment': '4', 'star': 'three star', 'price': 'ABCNo  average-spend ', 'environment': 6.8, 'service': 6.9}, {'classify': 'food', 'name': "millie's", 'comment': '67', 'star': 'beyond four star', 'price': '26', 'environment': 8.4, 'service': 8.4}, {'classify': 'food', 'name': 'J.Benato', 'comment': '226', 'star': 'five star', 'price': '47', 'environment': 8.5, 'service': 8.2}, {'classify': 'food', 'name': 'Satchi', 'comment': '2', 'star': 'four star', 'price': 'ABCNo  average-spend ', 'environment': 7.2, 'service': 7.2}, {'classify': 'food', 'name': 'KISSCAT', 'comment': '375', 'star': 'three star', 'price': '35', 'environment': 7.2, 'service': 6.5}, {'classify': 'food', 'name': 'JOy&peace', 'comment': '830', 'star': 'beyond four star', 'price': '165', 'environment': 7.7, 'service': 7.9}, {'classify': 'food', 'name': 'D:FUSE', 'comment': '15', 'star': 'four star', 'price': '14', 'environment': 7.1, 'service': 7.1}, {'classify': 'food', 'name': 'ginajone', 'comment': '1', 'star': 'four star', 'price': 'ABCNo  average-spend ', 'environment': 7.2, 'service': 7.6}, {'classify': 'food', 'name': 'YESCOLOR', 'comment': '1113', 'star': 'beyond four star', 'price': '36', 'environment': 7.4, 'service': 7.4}, {'classify': 'food', 'name': 'YEZI', 'comment': 'ABCNo comments', 'star': 'four star', 'price': 'ABCNo  average-spend ', 'environment': 6.9, 'service': 6.9}, {' ...
